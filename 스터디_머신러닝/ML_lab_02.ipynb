# %% [markdown]
# # Linear Regression

# %%
import tensorflow as tf
#Build graph using TF operations

# X and Y data
x_train = [1,2,3]
y_train = [1,2,3]

# tf.Varibale은 기존과 다름,([1])은 shape를 의미함 
W= tf.Variable(tf.random_normal([1]),name='weight')
b= tf.Variable(tf.random_normal([1]),name='bias')

hypothesis = x_train * W + b

cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#GradienDescent
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for step in range(2001):
    sess.run(train)
    if step % 20 == 0:
        print(step,sess.run(cost),sess.run(W),sess.run(b))

# train을 시킨다는 것은 그래프를 따라 cost와 H, W, b를 구하는 것
# Out:
# Exception ignored in: <bound method BaseSession.__del__ of <tensorflow.python.client.session.Session object at 0x117334f60>>
# Traceback (most recent call last):
#   File "/Users/arnorfati/anaconda/lib/python3.6/site-packages/tensorflow/python/client/session.py", line 587, in __del__
#     if self._session is not None:
# AttributeError: 'Session' object has no attribute '_session'
# 0 3.03272 [-0.62658769] [ 2.12673879]
# 20 0.759022 [-0.05349598] [ 2.24526596]
# 40 0.671265 [ 0.04330496] [ 2.16054988]
# 60 0.60949 [ 0.09276904] [ 2.06099296]
# 80 0.553547 [ 0.13583437] [ 1.96432233]
# 100 0.50274 [ 0.17648792] [ 1.87202418]
# 120 0.456596 [ 0.21519385] [ 1.78404772]
# 140 0.414688 [ 0.25207719] [ 1.70020437]
# 160 0.376626 [ 0.28722683] [ 1.62030101]
# 180 0.342058 [ 0.32072449] [ 1.54415286]
# 200 0.310663 [ 0.3526479] [ 1.47158349]
# 220 0.282149 [ 0.38307109] [ 1.40242445]
# 240 0.256252 [ 0.41206446] [ 1.33651567]
# 260 0.232732 [ 0.43969527] [ 1.27370441]
# ...

# %%
# reduce mean
t = [1.,2.,3.,4.]
tf.reduce_mean(t)

# 값을 보려면 어떻게 해야하는지 찾기
print(tf.Session.run(tf.reduce_mean(t)))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-34f53372ac1b> in <module>()
#       2 t = [1.,2.,3.,4.]
#       3 tf.reduce_mean(t)
# ----> 4 print(tf.Session.run(tf.reduce_mean(t)))
#
# TypeError: run() missing 1 required positional argument: 'fetches'

# %%
#code with placeholders
W= tf.Variable(tf.random_normal([1]),name='weight')
b= tf.Variable(tf.random_normal([1]),name='bias')

X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

hypothesis = X * W + b


cost = tf.reduce_mean(tf.square(hypothesis - y_train))

#GradienDescent
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

sess=tf.Session()
sess.run(tf.global_variables_initializer())
for step in range(2001):
    cost_val, W_val, b_val, _= sess.run([cost,W,b,train], feed_dict={X:[1,2,3],Y:[2.1,4.1,6.1]})
    if step%20 == 0:
        print(step,cost_val,W_val,b_val)
# Out:
# 0 32.8955 [-1.57002699] [ 0.48678243]
# 20 0.536261 [ 0.24394566] [ 1.20874298]
# 40 0.221024 [ 0.44070184] [ 1.22285926]
# 60 0.198326 [ 0.48233846] [ 1.17214286]
# 80 0.180101 [ 0.50812846] [ 1.1176995]
# 100 0.16357 [ 0.53138375] [ 1.06523287]
# 120 0.148557 [ 0.55342019] [ 1.01517689]
# 140 0.134922 [ 0.57440901] [ 0.96746796]
# 160 0.122538 [ 0.5944103] [ 0.92200071]
# 180 0.111291 [ 0.61347145] [ 0.8786701]
# 200 0.101077 [ 0.63163686] [ 0.83737582]
# 220 0.0917995 [ 0.64894855] [ 0.79802239]
# 240 0.0833737 [ 0.6654467] [ 0.76051819]
# 260 0.0757214 [ 0.68116951] [ 0.72477663]
# 280 0.0687713 [ 0.69615346] [ 0.69071466]
# 300 0.0624592 [ 0.71043313] [ 0.65825367]
# 320 0.0567265 [ 0.7240417] [ 0.62731814]
# 340 0.0515199 [ 0.73701072] [ 0.59783649]
# 360 0.0467912 [ 0.74937034] [ 0.56974018]
# 380 0.0424965 [ 0.76114893] [ 0.54296458]
# 400 0.038596 [ 0.77237409] [ 0.51744717]
# 420 0.0350535 [ 0.78307164] [ 0.49312913]
# 440 0.0318361 [ 0.79326648] [ 0.46995384]
# ...
