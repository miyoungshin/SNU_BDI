# %%
import tensorflow as tf

x_data = [[1, 2], [2, 3], [3, 1], [4, 3], [5, 3], [6, 2]] 
y_data = [[0], [0], [0], [1], [1], [1]]
# n개의 데이터를 주어줄 땐 None (여기선 6개)

X = tf.placeholder(tf.float32, shape=[None, 2])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([2, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')
# matrix를 활용하려면 matmul, bias는 나가는 값 sigmoid 함수는 tf.sigmoid를 이용해서 구현
# tf.exp(1.,1.+tf.matmul(tf.matmul(X.W)+b)

hypothesis = tf.sigmoid(tf.matmul(X, W) + b)

# cost 함수
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)


# 개인적인 주관에 따라? 
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# 앞선 회귀식과 동일
with tf.Session() as sess:   
   sess.run(tf.global_variables_initializer())
   for step in range(10001):
       cost_val, _ = sess.run([cost, train], feed_dict={X: x_data, Y: y_data})
       if step % 200 == 0:
           print(step, cost_val)

   # Accuracy report
   h, c, a = sess.run([hypothesis, predicted, accuracy],
                      feed_dict={X: x_data, Y: y_data})
   print("\nHypothesis: ", h, "\nCorrect (Y): ", c, "\nAccuracy: ", a)
# Out:
# 0 2.9104
# 200 0.511639
# 400 0.478854
# 600 0.46073
# 800 0.443882
# 1000 0.428126
# 1200 0.413321
# 1400 0.399361
# 1600 0.386163
# 1800 0.373663
# 2000 0.361809
# 2200 0.350558
# 2400 0.33987
# 2600 0.329713
# 2800 0.320053
# 3000 0.310863
# 3200 0.302115
# 3400 0.293784
# 3600 0.285846
# 3800 0.278278
# 4000 0.27106
# 4200 0.26417
# 4400 0.25759
# 4600 0.251303
# 4800 0.245292
# 5000 0.239541
# 5200 0.234036
# 5400 0.228762
# 5600 0.223708
# 5800 0.218861
# 6000 0.214209
# 6200 0.209742
# 6400 0.205451
# 6600 0.201325
# 6800 0.197356
# 7000 0.193536
# 7200 0.189857
# 7400 0.186312
# 7600 0.182895
# 7800 0.179598
# 8000 0.176416
# 8200 0.173343
# 8400 0.170375
# 8600 0.167505
# 8800 0.16473
# 9000 0.162045
# 9200 0.159445
# 9400 0.156928
# 9600 0.154488
# 9800 0.152124
# 10000 0.149831
#
# Hypothesis:  [[ 0.03088094]
#  [ 0.15903477]
#  [ 0.30554575]
#  [ 0.78107357]
#  [ 0.93938106]
#  [ 0.98010433]]
# Correct (Y):  [[ 0.]
#  [ 0.]
#  [ 0.]
#  [ 1.]
#  [ 1.]
#  [ 1.]]
# Accuracy:  1.0

# %%
import numpy as np
xy = np.loadtxt('data-03-diabetes.csv', delimiter=',', dtype=np.float32)
x_data = xy[:, 0:-1]
y_data = xy[:, [-1]]


X = tf.placeholder(tf.float32, shape=[None, 8])
Y = tf.placeholder(tf.float32, shape=[None, 1])

W = tf.Variable(tf.random_normal([8, 1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

hypothesis = tf.sigmoid(tf.matmul(X, W) + b)

cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.01).minimize(cost)


predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

with tf.Session() as sess:
   sess.run(tf.global_variables_initializer())

   feed = {X: x_data, Y: y_data}
   for step in range(10001):
       sess.run(train, feed_dict=feed)
       if step % 200 == 0:
           print(step, sess.run(cost, feed_dict=feed))
   h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict=feed)
   print("\nHypothesis: ", h, "\nCorrect (Y): ", c, "\nAccuracy: ", a)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-240480d25913> in <module>()
#       1 import numpy as np
# ----> 2 xy = np.loadtxt('data-03-diabetes.csv', delimiter=',', dtype=np.float32)
#       3 x_data = xy[:, 0:-1]
#       4 y_data = xy[:, [-1]]
#       5
#
# /Users/arnorfati/anaconda/lib/python3.6/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin)
#     896                 fh = iter(open(fname, 'U'))
#     897             else:
# --> 898                 fh = iter(open(fname))
#     899         else:
#     900             fh = iter(fname)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data-03-diabetes.csv'
